# %% [markdown]
# # Ytdlp Telegram Bot — Kaggle Launcher
# Run the cells from top to bottom. Credentials are entered securely at runtime.

# %%
# !git clone -q https://github.com/Telebotfaroff/Ytdlp.git || true
# %cd /kaggle/working/Ytdlp
# !git pull --ff-only

# %%
# !pip -q install -r requirements.txt
# !apt-get update -qq && apt-get install -y -qq ffmpeg aria2
# !ffmpeg -version | head -1
# !aria2c --version | head -1

# %%
import getpass, os
os.environ['BOT_TOKEN'] = getpass.getpass('BOT_TOKEN: ')
os.environ['TELEGRAM_API_ID'] = getpass.getpass('TELEGRAM_API_ID: ')
os.environ['TELEGRAM_API_HASH'] = getpass.getpass('TELEGRAM_API_HASH: ')
os.environ['DOWNLOAD_DIR'] = './downloads'
os.environ['TEMP_DIR'] = './tmp'
os.environ['MAX_TELEGRAM_FILE_SIZE'] = '2147483648'

# %%
# !python run.py
